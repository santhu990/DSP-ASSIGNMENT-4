# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import svm
x=np.array([[1,3],[1,2],[1,1.5],[1.5,2],[2,3],[2.5,1.5],[2,1],[3,1],[3,2],[3.5,1],[3.5,3]])
y=[0]*6+[1]*5

# %%
plt.scatter(x[:,0],x[:,1],c=y,s=50,alpha=0.9)

# %%
svm=svm.SVC(kernel='linear').fit(x,y)

# %%
X,Y=np.mgrid[0:4:200j,0:4:200j]

# %%
Z=svm.decision_function(np.c_[X.ravel(),Y.ravel()])

# %%
Z=Z.reshape(X.shape)

# %%
plt.contourf(X,Y,Z>0,alpha=0.6)
plt.contour(X,Y,Z,colors=['k'],linestyles=['-'],levels=[0])
plt.scatter(x[:,0],x[:,1],c=y,s=50,alpha=0.9)

# %%
plt.contourf(X,Y,Z>0,alpha=0.4)
plt.contour(X,Y,Z,colors=['k','k','k'],linestyles=['--','-','--'],levels=[-1,0,1])
plt.scatter(svm.support_vectors_[ :,0],svm.support_vectors_[ :,1],c=y,s=120,spacecolors='none')
plt.scatter(x[:,0],x[:,1],c=y,s=50,alpha=0.9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:4221, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4220 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4221     colors = mcolors.to_rgba_array(c)
#    4222 except (TypeError, ValueError) as err:
#
# File ~\anaconda3\lib\site-packages\matplotlib\colors.py:377, in to_rgba_array(c, alpha)
#     376 else:
# --> 377     rgba = np.array([to_rgba(cc) for cc in c])
#     379 if alpha is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\colors.py:377, in <listcomp>(.0)
#     376 else:
# --> 377     rgba = np.array([to_rgba(cc) for cc in c])
#     379 if alpha is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\colors.py:187, in to_rgba(c, alpha)
# ...
